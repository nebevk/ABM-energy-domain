# %% [markdown]
# # Building energy feedback in vpliv družbenega omrežja na varčevanje energije
#
#
# ### Azar 2017: A Novel Occupant-Focused Framework to Test Community-Scale Building Energy Feedback
#
# **Dropbox paper:** https://www.dropbox.com/scl/fi/td3u8qjqs4t0w5gpmgbtd/MAGAzar-2017-A-novel-occupant-focused-framework-to-test-community-scale-building-energy-feedback.paper?dl=0&rlkey=qryqm0cvec7urwu6u1vc6n45e
#
# **Visokonivojska skica modela:**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Testni model

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

# %%
#simple test 

oeciTest = 0.5
fbrTest = 1
suscTest = 0.1
Ntest = 2
sumOeciTest = oeciTest/Ntest

#simple enacba
newOeciTest = (1-fbrTest*suscTest)*oeciTest + fbrTest* suscTest * sumOeciTest

print("zacetni OECI", oeciTest)
print("Novi OECI", newOeciTest)
# Out:
# zacetni OECI 0.5
# Novi OECI 0.47500000000000003

# %% [markdown]
# ## Grajenje modela
#
# Ključni podatki:
#
#  - OECI → Occupant energy conservation index (Koliko akcij za varčevanje z energijo izvede stanovalec i v času t ), Vrednost je med 1 in 0
#  ![](https://paper-attachments.dropbox.com/s_430E5F067AF1D703221848C7C097B59E7251B520BA3C3BF77BF92C08DB98D5E4_1606248705075_image.png)
#
#  - BECI → Building Energy conservation index (Na nivoju stavbe, OECI vseh stanovalcev)
#  ![](https://paper-attachments.dropbox.com/s_430E5F067AF1D703221848C7C097B59E7251B520BA3C3BF77BF92C08DB98D5E4_1606249168877_image.png)
#
#  - EI → Energy intensity (Na poldagi BECI stavbe in Elasticity) Podatki so pridobljeni iz prejšnjih študij in poskusov.
#  ![](https://paper-attachments.dropbox.com/s_430E5F067AF1D703221848C7C097B59E7251B520BA3C3BF77BF92C08DB98D5E4_1606249273623_image.png)
#
#  - Percentage Energy Savings → Primerjava začetne in trenutne EI v procentih
#  ![](https://paper-attachments.dropbox.com/s_430E5F067AF1D703221848C7C097B59E7251B520BA3C3BF77BF92C08DB98D5E4_1606249389391_image.png)

# %% [markdown]
# ### Branje podatkov in ustvarjanje agentov

# %%
#agent = OECI, susceptibility, FBR 
agent1 = [1, 0.5, 1]
agent2 = [0, 0.5, 1]

# %% [markdown]
# ### Izdelava omrežja

# %% [markdown]
# ### Definicija obnašanja agentov

# %%
agentList = [agent1,agent2] #agente spravimo v seznam

print(agentList[1:])

plus = sum(agent[0]*agent[2] for agent in agentList[1:]) #Kalkulacija za testiranje 
print(plus)

# povzeto po Jensen enačba z abeh diffusion
def calculateBehaviour(time,agent):
    print(agentBehaviour)

    #test
    OECI = agent[0] #Nastavimo začetno obnašanje agenta
    print('Parametri', time, OECI)
    for i in range(time): # zanka za simulacijo poteka časa
        OECI = agentBehaviour + agent[1] * (sum(agent[0]*agent[2] for agent in agentList[1:])/sum(agent[2] for agent in agentList[1:])-agentBehaviour)
        print(agentBehaviour)
# Out:
# [[0, 0.5, 1]]
# 0

# %%
import
# Out:
#   File "<ipython-input-5-a43fc98aa4d0>", line 1
#     import
#           ^
# SyntaxError: invalid syntax
